# %%
# %matplotlib inline
import pandas as pd
cast = pd.read_csv('downloads/cast.csv')
cast = cast.set_index('type')
cast.head()
# Out:
#                       title  year      name                character     n
# type
# actor        Closet Monster  2015  Buffy #1                  Buffy 4  31.0
# actor       Suuri illusioni  1985    Homo $                   Guests  22.0
# actor   Battle of the Sexes  2017   $hutter          Bobby Riggs Fan  10.0
# actor  Secret in Their Eyes  2015   $hutter          2002 Dodger Fan   NaN
# actor            Steve Jobs  2015   $hutter  1988 Opera House Patron   NaN

# %%
cast.groupby('type').head()
# Out:
#                                                   title  year  \
# type
# actor                                    Closet Monster  2015
# actor                                   Suuri illusioni  1985
# actor                               Battle of the Sexes  2017
# actor                              Secret in Their Eyes  2015
# actor                                        Steve Jobs  2015
# actress                             Night of the Demons  2009
# actress  The Bad Lieutenant: Port of Call - New Orleans  2009
# actress  The Bad Lieutenant: Port of Call - New Orleans  2009
# actress                          A Woman of Distinction  1950
# actress                                Around the World  1943
#
#                                    name                character     n
# type
# actor                          Buffy #1                  Buffy 4  31.0
# actor                            Homo $                   Guests  22.0
# ...

# %%
#how many leading roles were available to actors and actresses in year 1950
cast.groupby('year').head()
# Out:
#                         title  year             name  \
# type
# actor          Closet Monster  2015         Buffy #1
# actor         Suuri illusioni  1985           Homo $
# actor     Battle of the Sexes  2017          $hutter
# actor    Secret in Their Eyes  2015          $hutter
# actor              Steve Jobs  2015          $hutter
# ...                       ...   ...              ...
# actor      Robbery Under Arms  1907       Lance Vane
# actor                Avatar 5  2025  Sam Worthington
# actor               100 Years  2115      Marko Zaror
# actress            Miss Jerry  1894  Blanche Bayliss
# actress             100 Years  2115      Shuya Chang
#
#                                     character     n
# type
# actor                                 Buffy 4  31.0
# actor                                  Guests  22.0
# actor                         Bobby Riggs Fan  10.0
# actor                         2002 Dodger Fan   NaN
# ...

# %%
#use groupby to determine how many roles are listed for pink panther movies
cast.groupby('character').head()
# Out:
#                         title  year                         name  \
# type
# actor          Closet Monster  2015                     Buffy #1
# actor         Suuri illusioni  1985                       Homo $
# actor     Battle of the Sexes  2017                      $hutter
# actor    Secret in Their Eyes  2015                      $hutter
# actor              Steve Jobs  2015                      $hutter
# ...                       ...   ...                          ...
# actress        Stuttur Frakki  1993    Sveinbj?rg ??rhallsd?ttir
# actress               Foxtrot  1988            Lilja ??risd?ttir
# actress             Skammdegi  1985           Dalla ??r?ard?ttir
# actress          U.S.S.S.S...  2003  Krist?n Andrea ??r?ard?ttir
# actress     Bye Bye Blue Bird  1999                 Rosa ? R?gvu
#
#                        character     n
# type
# actor                    Buffy 4  31.0
# actor                     Guests  22.0
# actor            Bobby Riggs Fan  10.0
# ...

# %%
#list orderby year each film Frank oz has played
frank=cast.groupby('name')

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
cast = pd.read_csv('downloads/cast.csv')
cast = cast.set_index('character')
movie = cast.loc['Batman']
print(movie)
cast.plot(kind = 'scatter' , x = 'type' , y = 'year')
cast.plot(kind = 'area' , stacked = 'true')
# Out:
#                                         title  year              name  \
# character
# Batman                  Batman Fights Dracula  1967       Jing Abalos
# Batman     Batman v Superman: Dawn of Justice  2016       Ben Affleck
# Batman                         Justice League  2017       Ben Affleck
# Batman                          Suicide Squad  2016       Ben Affleck
# Batman                  The LEGO Batman Movie  2017       Will Arnett
# ...                                       ...   ...               ...
# Batman                      Batman: The Movie  1966         Adam West
# Batman                                 Batman  1943      Lewis Wilson
# Batman                     The Cannonball Run  1981        Alfie Wise
# Batman                  Fight! Batman, Fight!  1973  Victor (II) Wood
# Batman                      Fatima Buen Story  1994   Janice de Belen
#
#               type     n
# character
# Batman       actor   1.0
# Batman       actor   1.0
# ...

# %%
movie = cast.loc['Superman']
print('movie')
# Out:
#                                              title  year  \
# character
# Superman                     Atom Man vs. Superman  1950
# Superman                   Corky of Gasoline Alley  1951
# Superman                                  Superman  1948
# Superman                         American Splendor  2003
# Superman                           My Amnesia Girl  2010
# Superman                              Puzzled Love  2011
# Superman             Supermen: World War, Fan Film  2018
# Superman            Attack of the Killer Tomatoes!  1978
# Superman        Batman v Superman: Dawn of Justice  2016
# Superman                            Justice League  2017
# Superman                              Mou mian bei  1995
# Superman                               Sam & Janet  2002
# Superman                              Certain Fury  1985
# Superman                                7 jin gong  1994
# Superman         Syoo-peo-maen-i-sseo-deon sa-na-i  2008
# ...

# %%
#how many years have been batman years
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
cast = pd.read_csv('downloads/cast.csv')
cast = cast.set_index('character')
movie = cast.loc['Batman'].sort_values('year')
print(movie)
# Out:
#                                  title  year                  name   type    n
# character
# Batman                       Nostalgie  1938         Jean Clarieux  actor  NaN
# Batman           Adventure in Diamonds  1940           Bobbie Hale  actor  NaN
# Batman                          Batman  1943          Lewis Wilson  actor  1.0
# Batman                Batman and Robin  1949         Robert Lowery  actor  1.0
# Batman                It's Not Cricket  1949          Leslie Dwyer  actor  5.0
# ...                                ...   ...                   ...    ...  ...
# Batman               Super Hero Shrink  2017       Brandon Hillock  actor  NaN
# Batman             Season of Mysteries  2018  Austin (III) Vickers  actor  NaN
# Batman                 Batman Unveiled  2018        Caillou Pettis  actor  NaN
# Batman     Batman the Rise of Red Hood  2018          Bryce Arnold  actor  NaN
# Batman                      JLA/United  2018         Anthony Caban  actor  NaN
#
# ...

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from IPython.core.display import HTML
release_dates = pd.read_csv('downloads/release_dates.csv')
release_dates.head()
release_dates.plot(kind = 'barh' , x = 'title' , y = 'year')
